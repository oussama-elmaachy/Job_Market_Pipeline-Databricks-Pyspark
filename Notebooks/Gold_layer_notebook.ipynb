# %%
# %load_ext autoreload
# %autoreload 2
# Enables autoreload; learn more at https://docs.databricks.com/en/files/workspace-modules.html#autoreload-for-python-modules
# To disable autoreload; run %autoreload 0

# %%
# %reload_ext autoreload

# %%
from utils.config import catalog_name,schema_name,silver_table
from transformations.gold_transformations import  create_gold_table

# %%
df=spark.read.table(f"{catalog_name}.{schema_name}.{silver_table}")
create_gold_table(df)
