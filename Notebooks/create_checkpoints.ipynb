# %%
dbutils.fs.rm("/Volumes/job_search_project_catalog/job_search_project_schema/job_search_project/checkpoints/silver/silver_table_checkpoint/", True)
dbutils.fs.mkdirs("/Volumes/job_search_project_catalog/job_search_project_schema/job_search_project/checkpoints/silver/silver_table_checkpoint/")

# %%
#dbutils.fs.rm("/Volumes/job_search_project_catalog/job_search_project_schema/job_search_project/checkpoints/silver/publisher_table_checkpoint/", True)
#dbutils.fs.mkdirs("/Volumes/job_search_project_catalog/job_search_project_schema/job_search_project/checkpoints/silver/publisher_table_checkpoint/")

# %%
dbutils.fs.rm("/Volumes/job_search_project_catalog/job_search_project_schema/job_search_project/checkpoints/silver/publisher_checkpoint/", True)
dbutils.fs.mkdirs("/Volumes/job_search_project_catalog/job_search_project_schema/job_search_project/checkpoints/silver/publisher_checkpoint/")

# %%
dbutils.fs.rm("/Volumes/job_search_project_catalog/job_search_project_schema/job_search_project/checkpoints/silver/employer_checkpoint/",True)
dbutils.fs.mkdirs("/Volumes/job_search_project_catalog/job_search_project_schema/job_search_project/checkpoints/silver/employer_checkpoint/")

# %%
dbutils.fs.rm("/Volumes/job_search_project_catalog/job_search_project_schema/job_search_project/checkpoints/silver/location_checkpoint/",True)
dbutils.fs.mkdirs("/Volumes/job_search_project_catalog/job_search_project_schema/job_search_project/checkpoints/silver/location_checkpoint/")

# %%
# %sh
ls /Volumes/job_search_project_catalog/job_search_project_schema/job_search_project/checkpoints/silver/

# %%
xc%load_ext autoreload
# %autoreload 2
# Enables autoreload; learn more at https://docs.databricks.com/en/files/workspace-modules.html#autoreload-for-python-modules
# To disable autoreload; run %autoreload 0

# %%
# %reload_ext autoreload

# %%
from transformations.silver_transformations import merge_silver_table

# %%
df=spark.read.table("job_search_project_catalog.job_search_project_schema.gold_table_job_search")
display(add_job_type(df))
